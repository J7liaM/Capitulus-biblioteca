# %%
import matplotlib.pyplot as pyplot

class Livro:
    def __init__(self, titulo, autor, genero, quantidade):
        self.titulo = titulo
        self.autor = autor
        self.genero = genero
        self.quantidade = quantidade

# Lista de livros
ArmazenamentoLiv = []

# Função de cadastrar livro
def cadastrar_livros():
    print("\n Cadastro de Livro ")
    titulo = input("Digite o título do livro: ")
    autor = input("Digite o autor do livro: ")
    genero = input("Digite o gênero do livro: ")
    quantidade = int(input("Digite a quantidade do livro: "))
    novo_livro = Livro(titulo, autor, genero, quantidade)
    ArmazenamentoLiv.append(novo_livro)
    print("📚 Livro cadastrado com sucesso!")

# Função para listar livros
def listar_livros():
    print("\n Lista de Livros ")
    if not ArmazenamentoLiv:
        print("Nenhum livro cadastrado.")
    else:
        for livro in ArmazenamentoLiv:
            print(f"Título: {livro.titulo}, Autor: {livro.autor}, Gênero: {livro.genero}, Quantidade: {livro.quantidade}")

# Função para buscar livro pelo título
def buscar_livro():
    print("\n Buscar Livro ")
    titulo_busca = input("Digite o título do livro que deseja buscar: ").lower()
    for livro in ArmazenamentoLiv:
        if livro.titulo.lower() == titulo_busca:
            print(f"Título: {livro.titulo}, Autor: {livro.autor}, Gênero: {livro.genero}, Quantidade: {livro.quantidade}")
            return
    print("Livro não encontrado.")

# Função para gerar gráfico
def gerar_grafico():
    if not ArmazenamentoLiv:
        print("Nenhum livro cadastrado. Não é possível gerar o gráfico.")
        return

    generos = {}
    for livro in ArmazenamentoLiv:
        if livro.genero in generos:
            generos[livro.genero] += livro.quantidade
        else:
            generos[livro.genero] = livro.quantidade

    pyplot.title("Quantidade de livros por gênero")
    pyplot.bar(generos.keys(), generos.values())
    pyplot.show()

# Menu principal
while True:
    print("\n Menu capitulus ")
    print("(1) Cadastrar livro")
    print("(2) Listar todos os livros")
    print("(3) Buscar um livro pelo título")
    print("(4) Gerar gráfico")
    print("(5) Sair")

    escolha = input("Selecione a função que deseja: ")

    if escolha == '1':
        cadastrar_livros()
    elif escolha == '2':
        listar_livros()
    elif escolha == '3':
        buscar_livro()
    elif escolha == '4':
        gerar_grafico()
        break
    elif escolha == '5':
        print("Obrigado pela presença, e boa leitura! 📖")
        break
    else:
        print("Opção inválida.")
# Out:
#  Menu Biblioteca
# (1) Cadastrar livro
# (2) Listar todos os livros
# (3) Buscar um livro pelo título
# (4) Gerar gráfico
# (5) Sair
# Selecione a função que deseja: 1
#
#  Cadastro de Livro
# Digite o título do livro: Dom casmurro
# Digite o autor do livro: Machado de Assis
# Digite o gênero do livro: Romance
# Digite a quantidade do livro: 5000
# 📚 Livro cadastrado com sucesso!
#
#  Menu Biblioteca
# (1) Cadastrar livro
# (2) Listar todos os livros
# (3) Buscar um livro pelo título
# (4) Gerar gráfico
# (5) Sair
# Selecione a função que deseja: Os inovadores
# Opção inválida.
#
#  Menu Biblioteca
# (1) Cadastrar livro
# (2) Listar todos os livros
# (3) Buscar um livro pelo título
# (4) Gerar gráfico
# (5) Sair
# Selecione a função que deseja: 1
#
#  Cadastro de Livro
# Digite o título do livro: Os inovadores
# Digite o autor do livro: Walter Isaacson
# Digite o gênero do livro: Biografia
# Digite a quantidade do livro: 2000
# 📚 Livro cadastrado com sucesso!
#
#  Menu Biblioteca
# ...
